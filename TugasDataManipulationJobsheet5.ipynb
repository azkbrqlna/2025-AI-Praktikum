# %% [markdown]
# <a href="https://colab.research.google.com/github/azkbrqlna/2025-AI-Praktikum/blob/main/TugasDataManipulationJobsheet5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Data Understanding
# - Load dataset
# ---

# %%
file_customers = 'customers.csv'
file_products = 'products.csv'
file_gasstations = 'gasstations.csv'
file_transactions = 'transactions_1k.csv'
file_yearmonth = 'yearmonth.csv'

# %% [markdown]
# ## Data Understanding
# - Preview dataset
# ---

# %%
df_customers = pd.read_csv(file_customers)
df_customers.head()
# Out:
#    CustomerID Segment Currency
# 0           3     SME      EUR
# 1           5     LAM      EUR
# 2           6     SME      EUR
# 3           7     LAM      EUR
# 4           9     SME      EUR

# %%
df_gasstations = pd.read_csv(file_gasstations)
df_gasstations.head()
# Out:
#    GasStationID  ChainID Country          Segment
# 0            44       13     CZE  Value for money
# 1            45        6     CZE          Premium
# 2            46       23     CZE            Other
# 3            47       33     CZE          Premium
# 4            48        4     CZE          Premium

# %%
df_products = pd.read_csv(file_products)
df_products.head()
# Out:
#    ProductID   Description
# 0          1  Rucní zadání
# 1          2         Nafta
# 2          3       Special
# 3          4         Super
# 4          5       Natural

# %%
df_transactions = pd.read_csv(file_transactions)
df_transactions.head()
# Out:
#    TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0              1  2012-08-24  09:41:00       31543  486621          3704
# 1              2  2012-08-24  10:03:00       46707  550134          3704
# 2              3  2012-08-24  10:03:00       46707  550134          3704
# 3              4  2012-08-24  13:53:00        7654  684220           656
# 4              5  2012-08-24  08:49:00       17373  536109           741
#
#    ProductID  Amount   Price
# 0          2      28  672.64
# 1          2      18  430.72
# 2         23       1  121.99
# 3          5       5  120.74
# 4          2      28  645.05

# %%
df_yearmonth = pd.read_csv(file_yearmonth)
df_yearmonth.head()
# Out:
#    CustomerID    Date  Consumption
# 0           5  201207       528.30
# 1           5  201302      1598.28
# 2           5  201303      1931.36
# 3           5  201304      1497.14
# 4           6  201203        51.06

# %% [markdown]
# ## Data Understanding
# - Merge tables
# ---

# %%
# Merge transaksi dengan customers
df_merged = pd.merge(df_transactions, df_customers,
                     on='CustomerID', how='left')

# Merge dengan gasstations
df_merged = pd.merge(df_merged, df_gasstations, on='GasStationID', how='left')

# Merge dengan products
df_merged = pd.merge(df_merged, df_products, on='ProductID', how='left')

# Siapkan kolom 'Date' dari df_transactions agar cocok dengan df_yearmonth (yyyymm)
df_merged['Date'] = pd.to_datetime(df_merged['Date'])
df_merged['YearMonth'] = df_merged['Date'].dt.strftime('%Y%m')

# Ubah 'Date' di df_yearmonth jadi string
df_yearmonth['Date'] = df_yearmonth['Date'].astype(str)

# Merge dengan df_yearmonth berdasarkan CustomerID dan YearMonth
df_merged = pd.merge(
    df_merged,
    df_yearmonth,
    left_on=['CustomerID', 'YearMonth'],
    right_on=['CustomerID', 'Date'],
    how='left'
)

# Rapikan kolom: buang kolom Date duplikat dan kolom YearMonth
df_merged.drop(columns=['Date_y', 'YearMonth'], inplace=True)
df_merged.rename(columns={'Date_x': 'Date'}, inplace=True)

# Ubah kolom 'Date' menjadi object (string)
df_merged['Date'] = df_merged['Date'].astype(str)

df_merged.head()
# Out:
#    TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0              1  2012-08-24  09:41:00       31543  486621          3704
# 1              2  2012-08-24  10:03:00       46707  550134          3704
# 2              3  2012-08-24  10:03:00       46707  550134          3704
# 3              4  2012-08-24  13:53:00        7654  684220           656
# 4              5  2012-08-24  08:49:00       17373  536109           741
#
#    ProductID  Amount   Price Segment_x Currency  ChainID Country Segment_y  \
# 0          2      28  672.64       KAM      CZK        4     CZE   Premium
# 1          2      18  430.72       KAM      CZK        4     CZE   Premium
# 2         23       1  121.99       KAM      CZK        4     CZE   Premium
# 3          5       5  120.74       KAM      CZK       30     CZE    Noname
# 4          2      28  645.05       KAM      CZK        2     CZE    Noname
#
#     Description  Consumption
# 0         Nafta    142991.10
# 1         Nafta    123653.64
# 2  Provoz.nápl.    123653.64
# 3       Natural     18107.97
# 4         Nafta     72690.54

# %% [markdown]
# ## Data Understanding
# - Preview Data types
# ---

# %%
print(df_merged.dtypes)
# Out:
# TransactionID      int64
# Date              object
# Time              object
# CustomerID         int64
# CardID             int64
# GasStationID       int64
# ProductID          int64
# Amount             int64
# Price            float64
# Segment_x         object
# Currency          object
# ChainID            int64
# Country           object
# Segment_y         object
# Description       object
# Consumption      float64
# dtype: object

# %% [markdown]
# ## Soal-1
# Buatlah table list Top 5 Customers yang memiliki nilai transaksi paling banyak
# ---

# %%
# Gabungkan berdasarkan CustomerID
merged = pd.merge(df_transactions, df_customers, on="CustomerID")

# Hitung jumlah transaksi dan total sales per CustomerID
sum = merged.groupby("CustomerID").agg(
    Amount=('TransactionID', 'count'),  # Banyaknya transaksi
    Sales=('Price', 'sum')              # Total uang yang dibelanjakan
).sort_values(by="Sales", ascending=False).head(5)

# Tampilkan dengan CustomerID sebagai index
sum.index.name = "Customer ID"
sum
# Out:
#              Amount    Sales
# Customer ID
# 19182            19  8618.54
# 16358             5  8400.94
# 31543            18  6161.50
# 12459            10  5974.47
# 30895            10  5940.01

# %% [markdown]
# ## Soal-2
# Buatlah list Top 5 Gas stations yang memiliki nilai transaksi paling banyak
# ---

# %%
# Gabungkan berdasarkan GasStationID
merged = pd.merge(df_transactions, df_gasstations, on="GasStationID")

# Hitung jumlah transaksi dan total sales per GasStationID
sum = merged.groupby("GasStationID").agg(
    Amount=('Amount', 'sum'),
    Sales=('Price', 'sum')
).sort_values(by="Sales", ascending=False).head(5)

# Tampilkan hasil
sum.index.name = "Gas Stations"
sum
# Out:
#               Amount    Sales
# Gas Stations
# 4347             370  8557.94
# 48               295  6868.67
# 3250             320  6744.47
# 1155             292  6701.69
# 2417             273  6065.16

# %% [markdown]
# ## Soal-3
# Buatlah list Top 5 Jenis produk yang memiliki nilai transaksi paling banyak
# ---

# %%
# Gabungkan transaksi dengan data produk
merged = pd.merge(df_transactions, df_products, on="ProductID")

# Hitung total Amount dan Sales per Produk
sum = merged.groupby("Description").agg(
    Amount=("Amount", "sum"),
    Sales=("Price", "sum"),
).sort_values(by="Sales", ascending=False).head(5)

# Tampilkan hasil
sum.index.name = "Products"
sum
# Out:
#             Amount      Sales
# Products
# Nafta        15230  345669.45
# Diesel +      1120   27261.03
# Natural       1045   24639.46
# Nafta Plus     317    7233.72
# Natural +      157    3999.92

# %% [markdown]
# ## Soal-4
# Buatlah deskripsi statistik untuk masing masing hari (23,24,25,26) pada dataset transaction_1k
# ---

# %%
# Konversi kolom Date ke datetime
df_transactions["Date"] = pd.to_datetime(df_transactions["Date"])

# Filter data untuk tanggal 23–26
filtered_df = df_transactions[df_transactions["Date"].dt.day.isin([
                                                                  23, 24, 25, 26])]

# Definisikan fungsi statistik
stat_funcs = ['count', 'mean', 'std', 'min',
              lambda x: x.quantile(0.25),
              'median',
              lambda x: x.quantile(0.75),
              'max']

# Buat ringkasan statistik
sum = filtered_df.groupby("Date").agg({
    'Amount': stat_funcs,
    'Price': stat_funcs
})

# Format ulang nama kolom statistik
stat_names = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']
sum.columns = pd.MultiIndex.from_tuples(
    [(col[0], stat_names[i % 8]) for i, col in enumerate(sum.columns)]
)

# Ganti nama kolom 'Price' menjadi 'Sales'
sum.rename(columns={"Price": "Sales"}, inplace=True)

# Tambahkan nama level kolom MultiIndex
sum.columns.names = ['Metric', 'Statistic']

# Tampilkan hasil
sum
# Out:
# Metric     Amount                                                    Sales  \
# Statistic   count       mean        std min    25%   50%    75%  max count
# Date
# 2012-08-23     10  29.600000  24.900692   1  21.25  26.5  35.25   91    10
# 2012-08-24    492  19.936992  21.949630   0   5.00  19.0  27.00  264   492
# 2012-08-25    425  18.880000  20.376114   0   4.00  17.0  26.00  154   425
# 2012-08-26     73  21.219178  18.932810   0   6.00  20.0  29.00  101    73
#
# Metric
# Statistic         mean         std    min      25%     50%      75%      max
# Date
# 2012-08-23  685.379000  534.046487  76.42  481.170  619.44  795.095  1994.71
# 2012-08-24  409.939736  488.269481   1.76   76.125  332.45  615.395  5762.49
# 2012-08-25  426.940071  453.134207   6.09  102.220  370.38  600.850  3600.84
# 2012-08-26  487.431370  429.192499   4.74  142.840  437.03  675.520  2303.75

# %% [markdown]
# ## Soal-5
# Carilah waktu terbaik (hari dan jam) dimana paling banyak user gas station melakukan transaksi
# ---

# %%
# Mengonversi kolom Amount dan Price ke numerik
df_transactions['Amount'] = pd.to_numeric(
    df_transactions['Amount'], errors='coerce')
df_transactions['Price'] = pd.to_numeric(
    df_transactions['Price'], errors='coerce')

# Menggabungkan Date dan Time menjadi satu kolom datetime
df_transactions['Datetime'] = pd.to_datetime(
    df_transactions['Date'].astype(
        str) + ' ' + df_transactions['Time'].astype(str),
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce'
)

# Mengekstrak tanggal dan jam
df_transactions['Date'] = df_transactions['Datetime'].dt.strftime('%Y-%m-%d')
# Jam dalam format 0-23
df_transactions['Hour'] = df_transactions['Datetime'].dt.hour

# Mengelompokkan data berdasarkan Date dan Hour, lalu menghitung Amount (sum) dan Sales (sum of Price)
result = df_transactions.groupby(['Date', 'Hour']).agg({
    'Amount': 'sum',  # Jumlah total Amount per jam
    'Price': 'sum'    # Total Price per jam
}).reset_index()

# Menampilkan hasil sebagai tabel DataFrame
result
# Out:
#           Date  Hour  Amount    Price
# 0   2012-08-23     9      79  1785.68
# 1   2012-08-23    20      26   720.89
# 2   2012-08-23    21      91  1994.71
# 3   2012-08-23    22      69  1603.51
# 4   2012-08-23    23      31   749.00
# ..         ...   ...     ...      ...
# 56  2012-08-26     9     310  7146.06
# 57  2012-08-26    10     120  2829.68
# 58  2012-08-26    11      67  1501.13
# 59  2012-08-26    12     152  3428.88
# 60  2012-08-26    13      43  1000.70
#
# [61 rows x 4 columns]

# %%
# Konversi kolom Amount dan Price ke numerik
df_transactions['Amount'] = pd.to_numeric(
    df_transactions['Amount'], errors='coerce')
df_transactions['Price'] = pd.to_numeric(
    df_transactions['Price'], errors='coerce')

# Gabungkan kolom Date dan Time menjadi kolom Datetime
df_transactions['Datetime'] = pd.to_datetime(
    df_transactions['Date'].astype(
        str) + ' ' + df_transactions['Time'].astype(str),
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce'
)

# Ekstrak Date dan Hour
df_transactions['Date'] = df_transactions['Datetime'].dt.strftime('%Y-%m-%d')
df_transactions['Hour'] = df_transactions['Datetime'].dt.hour

# Kelompokkan berdasarkan Date dan Hour, lalu hitung total Amount dan Price
grouped = df_transactions.groupby(['Date', 'Hour']).agg({
    'Amount': 'sum',
    'Price': 'sum'
}).reset_index()

# Ambil satu baris per Date dengan Amount terbesar (sesuai contohmu)
daily_max = grouped.loc[grouped.groupby('Date')['Amount'].idxmax()]

# Format ulang dan ubah nama kolom
daily_max = daily_max.rename(columns={'Hour': 'Time', 'Price': 'Gas Sales'})
daily_max['Gas Sales'] = daily_max['Gas Sales'].round(2)

# Jadikan kolom Date sebagai index
daily_max.set_index('Date', inplace=True)

# Tampilkan hasil
daily_max
# Out:
#             Time  Amount  Gas Sales
# Date
# 2012-08-23    21      91    1994.71
# 2012-08-24    16    1007   23528.20
# 2012-08-25     9    1034   19362.21
# 2012-08-26     8     348    7996.20

# %% [markdown]
# ## Soal-6
# Dari segi bisnis understanding, tujuan utama dari analisis data customer ini adalah?
# ---

# %% [markdown]
# <ol>
#     <li>Tujuan pertama adalah untuk mengetahui jenis produk dari gas station yang paling digemari oleh customer. Sehingga produsen dapat menambah stock terhadap jenis tersebut produk</li>
#     <li>Tujuan kedua mengetahui stasiun gas mana yang memiliki penjualan paling banyak. Sehingga produsen dapat memberi stock lebih ke stasiun gas tersebut</li>
#     <li>Tujuan terakhir untuk mengetahui jam berapa saja penjualan produk dibanjiri banyak customer, hal ini sangat membantu untuk mempersiapkan penjualan di jam-jam tersebut </li>
# </ol>

# %% [markdown]
# ---
#
# ### Tujuan Utama Analisis Data Customer (Business Understanding)
#
# Tujuan utama dari analisis data customer adalah untuk **memahami perilaku dan karakteristik pelanggan** guna membantu perusahaan dalam mengambil keputusan strategis. Berikut adalah beberapa tujuan utamanya:
#
# 1. **Segmentasi Pelanggan**
#    - Mengelompokkan pelanggan berdasarkan pola transaksi, frekuensi pembelian, dan total pengeluaran.
#    - Memberikan dasar untuk pemasaran yang lebih terarah (targeted marketing).
#
# 2. **Identifikasi Pelanggan Potensial**
#    - Menemukan pelanggan dengan nilai tinggi (high-value customers) agar dapat difokuskan dalam strategi loyalitas.
#
# 3. **Peningkatan Layanan dan Produk**
#    - Menyesuaikan produk atau layanan berdasarkan preferensi pelanggan yang teridentifikasi melalui data.
#
# 4. **Optimasi Strategi Promosi**
#    - Mengetahui jenis promosi yang paling efektif untuk masing-masing segmen pelanggan.
#
# 5. **Mengurangi Churn Rate**
#    - Memprediksi dan mencegah pelanggan yang berpotensi berhenti menggunakan layanan (churn).
#
# ---
#
# Dengan memahami pelanggan secara lebih mendalam melalui data, perusahaan dapat meningkatkan **pendapatan**, **retensi pelanggan**, dan **kepuasan pengguna**, sehingga mendorong pertumbuhan bisnis yang berkelanjutan.
