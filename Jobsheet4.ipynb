# %% [markdown]
# <a href="https://colab.research.google.com/github/azkbrqlna/2025-AI-Praktikum/blob/main/Jobsheet4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A. Latihan

# %% [markdown]
# ### 1.	Membaca berbagai format file menggunakan Pandas

# %% [markdown]
# a.	Membaca file CSV

# %%
import pandas as pd

df = pd.read_csv('./data.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
pd.options.display.max_rows
# Out:
# 9999

# %%
pd.options.display.max_rows = 9999
df = pd.read_csv('./data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# b.	Membaca file JSON

# %%
import pandas as pd

df = pd.read_json('./data.json')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# c.	Menggunakan Parameter pada Pandas Read

# %%
df = pd.read_csv('./data.csv', sep=',', header=0)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# d.	Membaca Custom Data

# %%
data = {
  "Duration": {
    "0": 60,
    "1": 60,
    "2": 60,
    "3": 45
  },
  "Pulse": {
    "0": 110,
    "1": 117,
    "2": 103,
    "3": 109
  },
  "Maxpulse": {
    "0": 130,
    "1": 145,
    "2": 135,
    "3": 175
  },
  "Calories": {
    "0": 409,
    "1": 479,
    "2": 340,
    "3": 282
  }
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282

# %% [markdown]
# ### 2.	Membuat dan Mengakses Elemen Series

# %% [markdown]
# a.	Membuat Series dari sebuah List Python

# %%
import pandas as pd

li = [1, 7, 2]
se = pd.Series(li)

print(se)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# b.	Mengakses Elemen pada Series

# %%
li = [1, 7, 2]
se = pd.Series(li)

print(se[0])
# Out:
# 1

# %% [markdown]
# c.	Memberi Label pada Series

# %%
li = [1, 7, 2]
se = pd.Series(li, index = ['x', 'y', 'z'])

print(se['x'])
# Out:
# 1

# %% [markdown]
# d.	Membuat Series dari Dictionary

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
se = pd.Series(calories)

print(se)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ### 3.	Membuat DataFrame

# %% [markdown]
# a.	Membuat DataFrame

# %%
import pandas as pd

df = pd.DataFrame(data= {"Nama" : ["Azka","Ilham","Pandu", "Riko"],
                         "Umur": [19, 19, 18,18],
                         "Kelas": [1, 1, 1, 1]})

# %%
df.columns
# Out:
# Index(['Nama', 'Umur', 'Kelas'], dtype='object')

# %%
df.columns.values[0] = "Nama Singkat"
df
# Out:
#   Nama Singkat  Umur  Kelas
# 0         Azka    19      1
# 1        Ilham    19      1
# 2        Pandu    18      1
# 3         Riko    18      1

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# b.	Mengakses Elemen pada DataFrame

# %%
df.iloc[0:2, [0,1]]
# Out:
#   Nama Singkat  Umur
# 0         Azka    19
# 1        Ilham    19

# %%
df.iloc[0:2, 0:2]
# Out:
#   Nama Singkat  Umur
# 0         Azka    19
# 1        Ilham    19

# %%
df.iloc[:, 0:2]
# Out:
#   Nama Singkat  Umur
# 0         Azka    19
# 1        Ilham    19
# 2        Pandu    18
# 3         Riko    18

# %%
df.loc[0:2, :'calories']
# Out:
#    calories
# 0       420
# 1       380
# 2       390

# %%
df.loc[0:2, ['calories', 'duration']]
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df['calories']
# Out:
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %%
df['calories'][0]
# Out:
# np.int64(420)

# %%
df[['calories']]
# Out:
#    calories
# 0       420
# 1       380
# 2       390

# %%
df[['calories']].loc[[0, 1]]
# Out:
#    calories
# 0       420
# 1       380

# %% [markdown]
# c.	Memberi Nama pada Index

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ['day1', 'day2', 'day3'])
print(df)
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# d.	Melihat DataFrame

# %%
df = pd.read_csv('./data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.shape
# Out:
# (169, 4)

# %%
df.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %% [markdown]
# e.	Membaca Informasi pada DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df['Calories'].mean(), df['Calories'].median(), df['Calories'].mode()[0]
# Out:
# (np.float64(375.79024390243904), 318.6, np.float64(300.0))

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000
